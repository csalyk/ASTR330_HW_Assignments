# %% [markdown]
# ## <font color="red">Student name:</font>

# %%
#Start all notebooks with this line.  It sets a lot of variables to values we want to use,
#and reads in some important packages of routines, too.
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The figure below shows opacity ($\kappa$) as a function of grain size (different curves; 0.1 $\mu$m sized grains to 1 cm sized grains) and wavelength of light (x axis).

# %% [markdown]
# ## Disk opacity

# %% [markdown]
# ![grainsize_plot2.png](attachment:grainsize_plot2.png)

# %% [markdown]
# ### 1(a): Explain in words what opacity is.  (Hint: Think about the *units* of opacity, and think about the distinction between opacity and optical depth).

# %% [markdown]
# <font color="red">*Comments from instructor: (please do not remove this cell)*</font>

# %% [markdown]
# ### 1(b): Using your understanding of opacity, derive an expression for how opacity depends on grain size if the wavelength of light is much smaller than the grain size.  Confirm that the figure matches your expression.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(c): Using your understanding of opacity, explain why opacity depends on the wavelength of light observed.  Explain qualitatively why each curve begins flat and then has a "kink", where it suddenly begins to fall to lower values.  Quantitatively estimate where the "kink" might occur, and compare to what you observe in the figure.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(d): Using the Minimum Mass Solar Nebula, and assuming  $\kappa=10^4\,\mathrm{cm}^2 \mathrm{g}^{-1}$ at 0.6 $\mu$m, estimate the optical depth ($\tau$) of a protoplanetary disk at 0.6 $\mu$m (visible wavelengths) at 1 AU, 10 AU, and 100 AU.  Discuss what you learned.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(e): Using the MMSN, and assuming $\kappa=0.1\,\mathrm{cm}^2 \mathrm{g}^{-1}$ at 1 mm, estimate the optical depth ($\tau$) of a protoplanetary disk at 1 mm at 1 AU, 10 AU, and 100 AU.   Discuss what you learned.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(f): What implication(s) do these calculations have for studying protoplanetary disks and planet formation?

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(g): Assuming the disk is optically thin, and that $h\nu<<kT$, derive an equation for flux density, $F_\nu$, of disk material at a temperature $T$, with opacity $\kappa$, and total mass $M_\mathrm{tot}$, at some frequency $\nu$, at a distance $d$.    (Hint: Consider the Rayleigh-Jeans limit of the blackbody radiation curve)

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(h):  Notice how the slope of the plot between 1mm and 3mm is different for different grain sizes.   If the opacity has the form $\kappa\propto \nu^\beta$ between these two wavelengths, use the plot to estimate the value of $\beta$ for 1$\mu$m-sized grains and for 1 cm-sized grains.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(i): Since the observed flux, $F_\nu$ depends on $\kappa$ if the disk is optically thin, measuring $F_\nu$ and two different frequencies can provide the grain size.  If the opacity has the form $\kappa\propto \nu^\beta$, derive an expression for the spectral index, $\alpha$, where $F_\nu\propto \nu^\alpha$, as a function of $\beta$.  What value of $\alpha$ would be consistent with 1$\mu$m-sized grains?  What value of $\alpha$ would be consistent with 1cm sized grains?

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(j): Explain the process by which an observer would use what you've learned in the last few questions to study the growth of grains during planet formation.  Also, discuss some of the ways in which such an analysis may be less simplistic than our discussion above.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(k): Assuming instead that the disk is optically thick, but that $h\nu<<kT$ still, estimate the value of the spectral index.  Explain how this may complicate attempts to interpret spectral index as a measure of grain size.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ## <font color="red"> Grade </font>

# %% [markdown]
# <font color="red"> Calculations: </font>

# %%
calculations_grade=0

# %% [markdown]
# <font color="red"> Concepts: </font>

# %%
concepts_grade=0

# %% [markdown]
# <font color="red"> Communication: </font>

# %%
communication_grade=0

# %% [markdown]
# <font color="red"> Total grade: </font>

# %%
print(calculations_grade+concepts_grade+communication_grade)
# Out:
# 0
